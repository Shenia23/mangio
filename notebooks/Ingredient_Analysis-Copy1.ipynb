# %%
import pandas as pd
import numpy as np

ingredients = pd.read_csv("../data/ingredientes.csv")

# %%
ingredients.head(10)
# Out:
#    Recipe_id   Ingrediente  Cantidad              Unidad  Indice  Grams  \
# 0      74154        harina      10.0                None     482    NaN
# 1      74154       chorizo     500.0              gramos     181    1.0
# 2      74154        alubia       1.5               tazas     535  150.0
# 3      74154         queso       1.0                taza      77  150.0
# 4      74154       lechuga       1.0            rebanada     634   60.0
# 5      74154       cebolla       3.0  cucharadas soperas     610   17.0
# 6      74154           sal       1.0               pizca     908    1.0
# 7      74146         pollo       1.0             pechuga     242  400.0
# 8      74146  nuez moscada       1.0            pellizco     891    1.0
# 9      74146   mantequilla     150.0              gramos     419    1.0
#
#    Total_Grams
# 0          NaN
# 1        500.0
# 2        225.0
# 3        150.0
# 4         60.0
# 5         51.0
# 6          1.0
# 7        400.0
# 8          1.0
# 9        150.0

# %%
ingredients.shape
# Out:
# (52384, 7)

# %%
ingredients['Cantidad'].isna().sum()
# Out:
# 7166

# %%
ingredients[ingredients['Unidad'] == 'None'].shape[0]
# Out:
# 17501

# %%
ingredients['Grams'].isna().sum()
# Out:
# 18440

# %%
recipe_nan_quantities_list = []
for index, value in ingredients.iterrows():
    recipe_nan_quantities = {}
    recipe_nan_quantities["Id_receta"]=value["Recipe_id"]

# %%
ingredients['Ingrediente'].value_counts()[:30].index.tolist()
# Out:
# ['sal',
#  'cebolla',
#  'huevo',
#  'ajo',
#  'pimienta',
#  'leche',
#  'aceite de oliva',
#  'azúcar',
#  'tomate',
#  'aceite',
#  'harina',
#  'mantequilla',
#  'agua',
#  'perejil',
#  'limón',
#  'queso',
#  'patata',
#  'pollo',
#  'pimiento',
#  'pimienta negra',
#  'vino',
#  'zanahoria',
#  'pimentón',
#  'vinagre',
#  'vainilla',
#  'canela',
#  'pan',
#  'laurel',
#  'arroz',
#  'orégano']

# %%
ingredients["Ingrediente"].value_counts().nlargest(n=30)
# Out:
# sal                4088
# cebolla            2493
# huevo              2349
# ajo                2244
# pimienta           2099
# leche              2049
# aceite de oliva    1887
# azúcar             1804
# tomate             1402
# aceite             1365
# harina             1264
# mantequilla        1199
# agua               1155
# perejil            1147
# limón               986
# queso               969
# patata              860
# pollo               813
# pimiento            722
# pimienta negra      664
# vino                638
# zanahoria           549
# pimentón            454
# vinagre             448
# vainilla            439
# canela              431
# pan                 431
# laurel              375
# arroz               370
# orégano             350
# Name: Ingrediente, dtype: int64

# %%
ingredients["Ingrediente"].value_counts().nsmallest(n=30)
# Out:
# queso herreño            1
# salchichón               1
# flan de huevo            1
# aceite de sésamo         1
# breca                    1
# queso munster            1
# paté de pimienta         1
# centeno                  1
# muesli                   1
# vino rosado              1
# chistorra                1
# galleta salada           1
# panga                    1
# sobao                    1
# leche de almendra        1
# salsa agridulce          1
# arroz con leche          1
# pan de maíz              1
# batido de chocolate      1
# merluza fresca           1
# guisantes en conserva    1
# aceite de palma          1
# queso en porciones       1
# zamburiñas               1
# leche de cabra           1
# zumo de mango            1
# perca                    1
# néctar de melocotón      1
# platija                  1
# infusión                 1
# Name: Ingrediente, dtype: int64

# %%
ingredients.sort_values(['Total_Grams'], ascending=False)[:30]
# Out:
#        Recipe_id    Ingrediente  Cantidad      Unidad  Indice   Grams  \
# 39438      38438           cava     750.0     botella     780  1000.0
# 40978      15182          leche     250.0        lata      27   330.0
# 35722      68912   nata montada      35.0       litro     424  1000.0
# 30533      30949      canelones      40.0     láminas     852   410.0
# 30167      33489      canelones      30.0     láminas     852   410.0
# 29401      61070      canelones      20.0     láminas     852   410.0
# 25891      26668           agua       5.0      litros     766  1000.0
# 15844      36774          cerdo       5.0  kilogramos     175  1000.0
# 29844      27557      canelones      12.0     láminas     852   410.0
# 37610      56565       gelatina      12.0     láminas     874   410.0
# 29535      59158         lasaña      12.0     láminas     884   410.0
# 21562      38515          queso      12.0     láminas      77   410.0
# 29218      72502      canelones      12.0     láminas     852   410.0
# 29575      57829         lasaña      12.0     láminas     884   410.0
# 30235      28832         lasaña      12.0     láminas     884   410.0
# 29901      52825         lasaña      12.0     láminas     884   410.0
# 29867      52991      canelones      10.0     láminas     852   410.0
# 1345       60167          queso      10.0     láminas      77   410.0
# 1344       60167  jamón de york      10.0     láminas     935   410.0
# 16108      60464           agua       4.0      litros     766  1000.0
# 40283      24593          leche       4.0      litros      27  1000.0
# 16388      12064          leche       4.0      litros      27  1000.0
# 26079      25460           agua       4.0      litros     766  1000.0
# 20075      22024           agua       4.0      litros     766  1000.0
# 43524      32810           agua       4.0      litros     766  1000.0
# 19199      23171       pimiento      12.0        lata     650   330.0
# 10857      26912          pollo      10.0      muslos     242   390.0
# 6347       59351           agua      15.0       vasos     766   250.0
# 29663      57818      canelones       8.0     láminas     852   410.0
# 29232      66004         lasaña       8.0     láminas     884   410.0
#
#        Total_Grams
# 39438     750000.0
# 40978      82500.0
# 35722      35000.0
# 30533      16400.0
# 30167      12300.0
# 29401       8200.0
# 25891       5000.0
# 15844       5000.0
# 29844       4920.0
# 37610       4920.0
# 29535       4920.0
# 21562       4920.0
# 29218       4920.0
# 29575       4920.0
# 30235       4920.0
# 29901       4920.0
# 29867       4100.0
# 1345        4100.0
# 1344        4100.0
# 16108       4000.0
# 40283       4000.0
# 16388       4000.0
# 26079       4000.0
# 20075       4000.0
# 43524       4000.0
# 19199       3960.0
# 10857       3900.0
# 6347        3750.0
# 29663       3280.0
# 29232       3280.0
