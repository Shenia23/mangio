# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import pattern.es as es
import regex as re

# %%
fr = pd.read_csv('../data/peso_frutas.csv')
vr = pd.read_csv('../data/peso_hortalizas.csv')
bedca = pd.read_csv('../data/bedca.csv',index_col=0)

# %%
fr = fr.drop('Peso bruto (g)',axis=1)

# %%
vg = fr.append(vr)

# %%
vg['Alimento'] = vg['Alimento'].apply(es.singularize).str.capitalize()

# %%
vg
# Out:
#                                  Alimento                          Medida  \
# 0                             Albaricoque                      3 unidades
# 1                                Arándano                 1 plato pequeño
# 2                               Carambola                 1 unidad grande
# 3                                  Cereza   1 plato pequeño ó 18 unidades
# 4                  Ciruela seca con hueso                      4 unidades
# ..                                    ...                             ...
# 32  Salsa concentrada de tomate comercial      1 cucharada sopera colmada
# 33             Soja germinada en conserva           10 cucharadas soperas
# 34                    Tomate maduro crudo                        1 unidad
# 35    Tomate pelado triturado en conserva           10 cucharadas soperas
# 36                              Zanahoria                        1 unidad
#
#     Peso neto (g)
# 0           180.0
# 1           120.0
# 2           200.0
# ...

# %%
def getMatch(ingredient, bedca):
    match = list(bedca[bedca['nombre'].str.contains(ingredient)]['nombre'])
    return (ingredient, match)

# %%
for ing in list(vg['Alimento']):
    print(getMatch(ing,bedca))
# Out:
# ('Albaricoque', ['Albaricoque'])
# ('Arándano', [])
# ('Carambola', [])
# ('Cereza', ['Cereza'])
# ('Ciruela seca con hueso', [])
# ('Ciruela', ['Ciruela, con piel, cruda', 'Ciruela, sin piel'])
# ('Dátil seco', [])
# ('Fresa/fresón', [])
# ('Granada', ['Granada'])
# ('Higo seco', [])
# ('Kiwi', ['Kiwi'])
# ('Lichi en conserva', [])
# ('Mandarina', ['Mandarina', 'Mandarina, congelada'])
# ('Mango', ['Mango, crudo'])
# ('Manzana', ['Manzana'])
# ('Melocotón', ['Melocotón', 'Melocotón en almíbar', 'Melocotón, desecado'])
# ('Melocotón en almíbar', ['Melocotón en almíbar'])
# ('Melocotón seco', [])
# ('Melón', ['Melón'])
# ('Naranja', ['Naranja'])
# ('Nectarina', ['Nectarina'])
# ('Níspero', ['Níspero, con piel, crudo'])
# ('Papaya pelada y troceada', [])
# ('Pasas seca', [])
# ('Pera', ['Pera', 'Pera, enlatada en almíbar'])
# ('Peras en almíbar', [])
# ('Piña en almíbar', ['Piña en almíbar'])
# ('Piña sin piel', [])
# ('Plátano', ['Plátano'])
# ('Pomelo', ['Pomelo'])
# ...
