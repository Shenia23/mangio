# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
df = pd.read_csv('../data/n_comensales_train.csv', index_col=0)
df = df.set_index('Recipe_id')
df.head()
# Out:
#            Total_Grams  Num_comensales            Categoria
# Recipe_id
# 1                168.0             4.0   Cócteles y bebidas
# 5                186.0             6.0  Recetas de Verduras
# 8                842.5             4.0   Cócteles y bebidas
# 10              1100.0             1.0   Cócteles y bebidas
# 27               631.0             4.0   Recetas de Pescado

# %%
df[df['Categoria'] == 'Recetas de Carne'].plot.scatter('Total_Grams', 'Num_comensales')
# Out:
# <AxesSubplot:xlabel='Total_Grams', ylabel='Num_comensales'>

# %%
f, ax = plt.subplots(figsize=(10, 10))
sns.kdeplot(data=df, x='Total_Grams', hue='Num_comensales', ax=ax)
ax.set_xlim(-1000, 6000)
# Out:
# /Users/sheniakuchumova/miniconda3/envs/lpro/lib/python3.9/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/sheniakuchumova/miniconda3/envs/lpro/lib/python3.9/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/sheniakuchumova/miniconda3/envs/lpro/lib/python3.9/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/sheniakuchumova/miniconda3/envs/lpro/lib/python3.9/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# (-1000.0, 6000.0)

# %%
sns.pairplot(data=df, hue='Categoria', height=8)

# %%
df[(~df['Num_comensales'].isna()) & (df['Categoria']=='Recetas de Carne')].sort_values('Total_Grams',ascending=False)
# Out:
#            Total_Grams  Num_comensales         Categoria
# Recipe_id
# 20836           4807.0             2.0  Recetas de Carne
# 20602           4017.5             2.0  Recetas de Carne
# 21046           3526.0             1.0  Recetas de Carne
# 21113           3142.0             5.0  Recetas de Carne
# 20669           2710.0             4.0  Recetas de Carne
# ...                ...             ...               ...
# 20714            346.0             2.0  Recetas de Carne
# 1734             183.0             4.0  Recetas de Carne
# 6592             120.0             8.0  Recetas de Carne
# 9869             101.0             4.0  Recetas de Carne
# 14042             52.5             4.0  Recetas de Carne
#
# [96 rows x 3 columns]

# %%
model_df = df[~df['Num_comensales'].isna()].copy()
problem_df = df[df['Num_comensales'].isna()].copy()

# %%
X = model_df[['Total_Grams','Categoria']]
Y = model_df['Num_comensales']

# %%
X['Categoria'].nunique()
# Out:
# 17

# %%
prepro = ColumnTransformer(transformers=[
    ('num', StandardScaler(), ['Total_Grams']),
    ('cat', OneHotEncoder(), ['Categoria'])
])
pipe = Pipeline(steps=[('preprocessor', prepro),
                      ('classifier', LinearRegression())])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)

# %%
pipe.fit(X_train, Y_train)
print("model score: %.3f" % pipe.score(X_test, Y_test))
# Out:
# model score: -0.036

# %%
y_pred = pipe.predict(X_test)

# %%
mean_squared_error(Y_test,y_pred)
# Out:
# 10.040482323136207

# %%
Y_test
# Out:
# Recipe_id
# 7006      2.0
# 8012      3.0
# 16343     4.0
# 8056      2.0
# 9584      4.0
#          ...
# 10886     8.0
# 7643      2.0
# 10728     1.0
# 12840     2.0
# 10821    10.0
# Name: Num_comensales, Length: 197, dtype: float64

# %%
y_pred
# Out:
# array([5.78371358, 4.10196435, 5.47744429, 5.38282061, 5.13272954,
#        2.84321968, 4.35568498, 5.14504964, 5.92336031, 5.47711648,
#        4.22445574, 5.24295533, 5.30676886, 4.70078623, 5.025973  ,
#        3.07062984, 5.41767766, 4.94434849, 4.44141628, 4.62888673,
#        4.42416266, 4.52395345, 3.5626517 , 4.77177723, 4.85638635,
#        6.04947266, 5.04749914, 3.59324723, 4.82972453, 4.24968638,
#        7.40125302, 6.22254088, 4.22123949, 4.29518138, 5.27114692,
#        4.23060296, 3.42672014, 5.35397339, 4.34795867, 4.1289821 ,
#        5.07686466, 4.12049278, 3.59794583, 6.06389627, 4.27868165,
#        4.87445229, 5.1708373 , 4.32424714, 4.74074463, 3.39601534,
#        4.27955581, 5.02131083, 4.58670643, 4.54602593, 5.39811837,
#        4.7018446 , 6.23674595, 5.36533745, 5.36761438, 4.84691606,
#        5.19159855, 4.74158002, 6.15085993, 4.70253454, 4.97814928,
#        4.43449786, 3.87166655, 5.83069957, 4.89417523, 4.92886837,
#        5.27223962, 5.35222508, 4.79271826, 4.45056051, 5.46990592,
#        4.71127394, 3.64853773, 4.27955581, 5.05263481, 4.74842784,
#        4.47082085, 4.06685059, 5.11401703, 4.00444831, 4.77545364,
#        4.96427177, 5.35768857, 5.1697446 , 3.47390996, 4.91051105,
#        4.25020523, 4.21839847, 4.97137455, 4.25217208, 4.72945133,
#        4.36347498, 5.22831318, 3.60264443, 4.3713424 , 3.71274551,
#        6.11416036, 4.65769962, 4.69157324, 5.25104129, 5.3445762 ,
#        4.43952008, 5.10505691, 5.3246891 , 4.70883786, 4.50891056,
#        4.79606945, 4.55586021, 4.32516427, 4.73549968, 5.27136546,
#        4.2251732 , 5.4907752 , 5.36566133, 4.80084299, 4.35316483,
#        3.93015413, 4.17611108, 5.16846075, 5.28294806, 4.34395867,
#        5.0935017 , 4.25123177, 5.3268745 , 4.93782849, 4.29253079,
#        4.50293489, 5.22853172, 4.59096795, 3.63083603, 4.89277317,
#        4.84687988, 4.75498402, 5.07929663, 5.38522062, 4.07044723,
#        3.37439974, 4.70573954, 4.92894146, 5.99187245, 4.25354961,
#        4.71098449, 4.45388404, 5.14646622, 4.34795867, 3.69661642,
#        4.58801766, 5.40915462, 4.53975905, 4.58754844, 4.78248567,
#        5.36315205, 5.53841681, 5.20700558, 4.39919954, 5.24601488,
#        4.4810922 , 3.61903489, 5.02338695, 5.29015986, 4.2886252 ,
#        3.38202881, 3.39597251, 4.53841339, 3.39601534, 4.40805039,
#        5.9393137 , 3.59455847, 3.85602627, 4.26174484, 4.56700573,
#        4.3900705 , 5.83268149, 6.13140991, 4.69743529, 3.9749929 ,
#        4.81005597, 4.77938736, 5.40860827, 4.70799803, 4.62331397,
#        6.02652602, 4.22754341, 5.46017967, 3.01575662, 4.95866283,
#        3.65400121, 5.06877543, 4.16660461, 5.14631542, 5.21651205,
#        3.65684223, 5.24743539])

# %%
confusion_matrix(Y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-ca2d544c3276> in <module>
# ----> 1 confusion_matrix(Y_test,y_pred)
#
# ~/miniconda3/envs/lpro/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/miniconda3/envs/lpro/lib/python3.9/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     294
#     295     """
# --> 296     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     297     if y_type not in ("binary", "multiclass"):
#     298         raise ValueError("%s is not supported" % y_type)
#
# ~/miniconda3/envs/lpro/lib/python3.9/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      90
#      91     if len(y_type) > 1:
# ---> 92         raise ValueError("Classification metrics can't handle a mix of {0} "
#      93                          "and {1} targets".format(type_true, type_pred))
#      94
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets

# %%
print(classification_report(Y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-68e4201b38cd> in <module>
# ----> 1 print(classification_report(Y_test,y_pred))
#
# ~/miniconda3/envs/lpro/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/miniconda3/envs/lpro/lib/python3.9/site-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1964     """
#    1965
# -> 1966     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1967
#    1968     if labels is None:
#
# ~/miniconda3/envs/lpro/lib/python3.9/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      90
#      91     if len(y_type) > 1:
# ---> 92         raise ValueError("Classification metrics can't handle a mix of {0} "
#      93                          "and {1} targets".format(type_true, type_pred))
#      94
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
